# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r'/Users/nazenirustemli/Desktop/python_/appstore_games.csv')

# %%
#Sudoku oyunların sayını tapın

# %%
data[data['Name'].str.contains('sudoku',case=False)].shape
# Out:
# (114, 18)

# %%
data[data['Name'].str.contains('sudoku',case=False)]['Name'].nunique()
# Out:
# 112

# %%
#Subtitle-da NA faizini tapın

# %%
round(data['Subtitle'].isna().sum()/len(data)*100)
# Out:
# 69

# %%
# Ən çox hansı developerin oyunu datada yer alır

# %%
data['Developer'].value_counts().head(3)
# Out:
# Tapps Tecnologia da Informa\xe7\xe3o Ltda.    123
# Vikash Patel                                  107
# Netsummit Marketing, Inc.                      95
# Name: Developer, dtype: int64

# %%
data['Developer'].mode()
# Out:
# 0    Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Name: Developer, dtype: object

# %%
# Multi-language oyunlar ümumi oyunların neçə faizini təşkil edir

# %%
data[data['Languages'].fillna('No info').str.contains(',')].shape[0]/len(data)*100
# Out:
# 25.75998118421826

# %%
#2015ci il üzrə ən çox hansı janrda oyun satılmışdır ( genres column)

# %%
data['Original Release Date']=pd.to_datetime(data['Original Release Date'])
# Out:
# /Users/nazenirustemli/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '23/07/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /Users/nazenirustemli/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '18/07/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /Users/nazenirustemli/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '30/07/2008' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
f1=data['Original Release Date'].dt.year==2015
data[f1]['Genres'].mode()
# Out:
# 0    Games, Puzzle, Strategy
# Name: Genres, dtype: object

# %%
#Oyun sayının illər üzrə paylanmasını göstərin

# %%
data.groupby(data['Original Release Date'].dt.year).agg({'Name':'count'})
# Out:
#                        Name
# Original Release Date
# 2008                     47
# 2009                    176
# 2010                    277
# 2011                    490
# 2012                    729
# 2013                   1161
# 2014                   1893
# 2015                   2216
# 2016                   3126
# 2017                   2818
# 2018                   2504
# 2019                   1570

# %%
data.head(2)
# Out:
#                                                  URL         ID     Name  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427   Sudoku
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400  Reversi
#
#   Subtitle                                           Icon URL  \
# 0      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# 0                  4.0             3553.0   2.99              NaN
# 1                  3.5              284.0   1.99              NaN
#
#                                          Description  \
# 0  Join over 21,000,000 of our fans and download ...
# 1  The classic game of Reversi, also known as Oth...
#
#                   Developer Age Rating  \
# 0  Mighty Mighty Good Games         4+
# 1          Kiss The Machine         4+
#
# ...
